# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import mne
import sklearn

# path
file_path = '/Users/ulasayyilmaz/Desktop/POM Super Junior/Neuro/EEG_Neuro_Project/AA0005.vhdr'

# Read the EEG data
raw = mne.io.read_raw_brainvision(file_path)

# Print information about the data
print(raw)
# Out:
# Extracting parameters from /Users/ulasayyilmaz/Desktop/POM Super Junior/Neuro/EEG_Neuro_Project/AA0005.vhdr...
# Setting channel info structure...
# <RawBrainVision | AA0005.eeg, 10 x 189342 (757.4 s), ~13 kB, data not loaded>
# /var/folders/xx/n40fck0j351db72x3rp26qq00000gn/T/ipykernel_17269/1490716975.py:11: RuntimeWarning: Channels contain different highpass filters. Lowest (weakest) filter setting (0.00 Hz) will be stored.
#   raw = mne.io.read_raw_brainvision(file_path)

# %%
print(raw.info)
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: F3, F4, C3, Cz, C4, P3, P4, accX, accY, accZ
#  chs: 10 misc
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2023-11-19 19:29:59 UTC
#  nchan: 10
#  projs: []
#  sfreq: 250.0 Hz
# >

# %%
raw.plot(duration=1, n_channels=10)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
# set up and fit the ICA
ica = mne.preprocessing.ICA(n_components=20, random_state=97, max_iter=800)
ica.fit(raw, )
ica.exclude = [1, 2]  # details on how we picked these are omitted here
ica.plot_properties(raw, picks=ica.exclude)
# Out:
# /var/folders/xx/n40fck0j351db72x3rp26qq00000gn/T/ipykernel_17269/3318433905.py:3: RuntimeWarning: The data has not been high-pass filtered. For good ICA performance, it should be high-pass filtered (e.g., with a 1.0 Hz lower bound) before fitting ICA.
#   ica.fit(raw)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 # set up and fit the ICA
#       2 ica = mne.preprocessing.ICA(n_components=20, random_state=97, max_iter=800)
# ----> 3 ica.fit(raw)
#       4 ica.exclude = [1, 2]  # details on how we picked these are omitted here
#       5 ica.plot_properties(raw, picks=ica.exclude)
#
# File <decorator-gen-277>:12, in fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#
# File ~/Desktop/POM Super Junior/Neuro/EEG_Neuro_Project/.venv/lib/python3.11/site-packages/mne/preprocessing/ica.py:703, in ICA.fit(self, inst, picks, start, stop, decim, reject, flat, tstep, reject_by_annotation, verbose)
#     696     if ignored_params:
#     697         warn(
#     698             f"The following parameters passed to ICA.fit() will be "
#     699             f"ignored, as they only affect raw data (and it appears "
#     700             f'you passed epochs): {", ".join(ignored_params)}'
#     701         )
# --> 703 picks = _picks_to_idx(
#     704     inst.info, picks, allow_empty=False, with_ref_meg=self.allow_ref_meg
#     705 )
#     706 _check_for_unsupported_ica_channels(
#     707     picks, inst.info, allow_ref_meg=self.allow_ref_meg
#     708 )
#     710 # Actually start fitting
#
# File ~/Desktop/POM Super Junior/Neuro/EEG_Neuro_Project/.venv/lib/python3.11/site-packages/mne/_fiff/pick.py:1271, in _picks_to_idx(info, picks, none, exclude, allow_empty, with_ref_meg, return_kind, picks_on)
#    1269     raise ValueError("picks must be 1D, got %sD" % (picks.ndim,))
#    1270 if picks.dtype.char in ("S", "U"):
# -> 1271     picks = _picks_str_to_idx(
#    1272         info,
#    1273         picks,
#    1274         exclude,
#    1275         with_ref_meg,
#    1276         return_kind,
#    1277         extra_repr,
#    1278         allow_empty,
#    1279         orig_picks,
#    1280     )
#    1281     if return_kind:
#    1282         picked_ch_type_or_generic = picks[1]
#
# File ~/Desktop/POM Super Junior/Neuro/EEG_Neuro_Project/.venv/lib/python3.11/site-packages/mne/_fiff/pick.py:1343, in _picks_str_to_idx(info, picks, exclude, with_ref_meg, return_kind, extra_repr, allow_empty, orig_picks)
#    1341             picks_generic = _pick_data_or_ica(info, exclude=exclude)
#    1342         if len(picks_generic) == 0 and orig_picks is None and not allow_empty:
# -> 1343             raise ValueError(
#    1344                 "picks (%s) yielded no channels, consider "
#    1345                 "passing picks explicitly" % (repr(orig_picks) + extra_repr,)
#    1346             )
#    1348 #
#    1349 # second: match all to channel names
#    1350 #
#    1352 bad_names = []
#
# ValueError: picks (NoneNone, treated as "data") yielded no channels, consider passing picks explicitly

# %%
# movement = mne.preprocessing.annotate_movement(raw, )
# print(movement.info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 movement = mne.preprocessing.annotate_movement(raw)
#       2 print(movement.info)
#
# TypeError: annotate_movement() missing 1 required positional argument: 'pos'
